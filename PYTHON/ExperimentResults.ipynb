# %% [markdown]
# # Displaying Experiment Results after Evaluation (loading from dataframe)

# %%
#Basics
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

#Evaluation
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, recall_score, f1_score, precision_score

#PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import SubsetRandomSampler

#Torchvision
import torchvision
from torchvision import transforms, datasets

#Data
from FRDEEP import FRDEEPF
from MiraBest import MiraBest_full

#My Functions / Models
from models_new import *
from utils import *

#Other
import pickle
from tqdm import tqdm
import PIL
from torchsummary import summary
from models.networks_other import init_weights

# %%
data_options = ['FRDEEP-F','MiraBest','MiraBestNOHYBRID','MiraBestNOUNC','automatic']
if 'df' in locals():
    del df
# The data in the dictionaries is in the format (form):
form = ['data_train','net_name','date','lr','epoch','auc','friP','friN','friiN','friiP','frirecall','friirecall','friprecision','friiprecision','frif1','friif1','fpr','tpr','thresholds']
### Add models trained on each dataset
for data in data_options[:-1]:
    # Load in dict:
    pickle_in = open(f'evaluated_models_{data}.pickle','rb')
    evaluated_models = pickle.load(pickle_in)
    pickle_in.close()

    # Load dict into dataframe
    df_temp = pd.DataFrame.from_dict(evaluated_models,orient='index',columns=form)
    # Make keys of dict into their own column
    df_temp['model'] = df_temp.index
    # Add data_evaluation column
    if data == 'MiraBest':
        df_temp = df_temp.assign(data_eval = f'{data}HYBRID')
    else:
        df_temp = df_temp.assign(data_eval = f'{data}')
    
    # Assign df or stack onto df
    if 'df' not in locals(): #Initialise
        df = df_temp
    elif 'df' in locals(): #Stack
        df = pd.concat([df,df_temp],axis=0)
    else:
        print('Something went wrong!')
    
# Reset index to numeric digits
df = df.reset_index(drop=True)
#df[df.date!='TEST'].sort_values(by='date',ascending=False).head()

# %%
# Add accuracy column
df['accuracy']=(df.friP+df.friiP)/(df.friP+df.friiP+df.friiN+df.friN)
#accuracy = (df.friP.to_numpy()+df.friiP.to_numpy())/(df.friP.to_numpy()+df.friiP.to_numpy()+df.friiN.to_numpy()+df.friN.to_numpy()) #NUMPY ACCURACY

# %%
df = df.sort_values(by=['accuracy','auc'],ascending=False)
df[(df.data_train != 'FRDEEP-F') & (df.net_name != 'transfer_original') & (df.data_eval=='FRDEEP-F')][['auc','accuracy','data_train','data_eval','net_name','model','date']].head(10)
# Out:
#           auc  accuracy        data_train data_eval     net_name  \
# 125  0.896116  0.855389  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 115  0.849442  0.853944  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 116  0.846905  0.847333  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 104  0.831645  0.836611  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 127  0.930676  0.835389  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 103  0.846351  0.834667  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 119  0.844833  0.832722  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 123  0.830156  0.828056  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 108  0.822033  0.826667  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
# 102  0.825743  0.825222  MiraBestNOHYBRID  FRDEEP-F  AGRadGalNet
#
#                                                  model      date
# 125  0624Exp2-softmax-MiraBestNOHYBRIDAdam-AGRadGal...  0624Exp2
# 115  0622Exp1-tanh-MiraBestNOHYBRIDAdam-AGRadGalNet...  0622Exp1
# 116  0624Exp2-std_mean_norm-MiraBestNOHYBRIDAdam-AG...  0624Exp2
# 104  0622Exp1-sigmoid-MiraBestNOHYBRIDAdam-AGRadGal...  0622Exp1
# 127  0709Exp2-softmax-MiraBestNOHYBRIDAdam-AGRadGal...  0709Exp2
# 103  0624Exp2-range_norm-MiraBestNOHYBRIDAdam-AGRad...  0624Exp2
# 119  0624Exp2-tanh-MiraBestNOHYBRIDAdam-AGRadGalNet...  0624Exp2
# 123  0624Exp2-tanh-MiraBestNOHYBRIDAdam-AGRadGalNet...  0624Exp2
# 108  0624Exp2-std_mean_norm-MiraBestNOHYBRIDAdam-AG...  0624Exp2
# 102  0624Exp2-sigmoid-MiraBestNOHYBRIDAdam-AGRadGal...  0624Exp2

# %% [markdown]
# # Preping the Dataframes

# %%
#df['normalisation']=df.model.str.split('-')[1]
exp1 = df.loc[df.date=='0709Exp1'].copy()
exp1['normalisation']=exp1.model.str.split('-').str[1]
exp1['aggregation']=exp1.model.str.split('-').str[-3].str[11:]
exp1['f1']=(exp1.frif1+exp1.friif1)/2
exp1['precision']=(exp1.friprecision+exp1.friiprecision)/2
exp1['recall']=(exp1.frirecall+exp1.friirecall)/2
view1 = exp1[['data_eval', 
              'normalisation', 
              'aggregation',
              'accuracy', 
              'auc',
              'f1',
              'precision',
              'recall'
             ]]

exp2 = df.loc[df.date=='0709Exp2'].copy()
exp2['normalisation']=exp2.model.str.split('-').str[1]
exp2['aggregation']=exp2.model.str.split('-').str[-3].str[11:]
exp2['f1']=(exp2.frif1+exp2.friif1)/2
exp2['precision']=(exp2.friprecision+exp2.friiprecision)/2
exp2['recall']=(exp2.frirecall+exp2.friirecall)/2
view2 = exp2[['data_eval', 
              'normalisation', 
              #'aggregation',
              'accuracy', 
              'auc',
              'frif1','friif1',
              'friprecision','friiprecision',
              'frirecall','friirecall'
              #'f1',
              #'precision',
              #'recall'
             ]]
print('Original keys: \n', df.keys())
print('Evaluation keys: \n', exp1.keys())
# Out:
# Original keys:
#  Index(['data_train', 'net_name', 'date', 'lr', 'epoch', 'auc', 'friP', 'friN',
#        'friiN', 'friiP', 'frirecall', 'friirecall', 'friprecision',
#        'friiprecision', 'frif1', 'friif1', 'fpr', 'tpr', 'thresholds', 'model',
#        'data_eval', 'accuracy'],
#       dtype='object')
# Evaluation keys:
#  Index(['data_train', 'net_name', 'date', 'lr', 'epoch', 'auc', 'friP', 'friN',
#        'friiN', 'friiP', 'frirecall', 'friirecall', 'friprecision',
#        'friiprecision', 'frif1', 'friif1', 'fpr', 'tpr', 'thresholds', 'model',
#        'data_eval', 'accuracy', 'normalisation', 'aggregation', 'f1',
#        'precision', 'recall'],
#       dtype='object')

# %% [markdown]
# # Experiment 1 Results:

# %% [markdown]
# # TODO:
# - Add columns for normalisation and aggregation
# - Add colums for performative ratio on other datasets?

# %%
view1.sort_values(by = ['normalisation', 'auc'], ascending = False).round(2)
# Out:
#             data_eval normalisation aggregation  accuracy   auc    f1  \
# 574     MiraBestNOUNC    range_norm          ft      0.93  0.97  0.92
# 580     MiraBestNOUNC    range_norm          ft      0.92  0.96  0.92
# 286    MiraBestHYBRID    range_norm          ft      0.92  0.96  0.92
# 280    MiraBestHYBRID    range_norm          ft      0.84  0.92  0.84
# 427  MiraBestNOHYBRID    range_norm          ft      0.84  0.92  0.84
# 433  MiraBestNOHYBRID    range_norm          ft      0.84  0.90  0.84
# 146          FRDEEP-F    range_norm          ft      0.89  0.90  0.88
# 133          FRDEEP-F    range_norm          ft      0.79  0.85  0.79
# 139          FRDEEP-F    range_norm          ft      0.74  0.80  0.74
# 587     MiraBestNOUNC    range_norm          ft      0.73  0.77  0.72
# 440  MiraBestNOHYBRID    range_norm          ft      0.69  0.72  0.67
# 293    MiraBestHYBRID    range_norm          ft      0.67  0.70  0.65
#
#      precision  recall
# 574       0.94    0.92
# 580       0.92    0.92
# 286       0.92    0.92
# 280       0.85    0.84
# 427       0.86    0.84
# 433       0.84    0.84
# 146       0.88    0.88
# 133       0.80    0.79
# 139       0.74    0.74
# 587       0.78    0.74
# 440       0.74    0.69
# 293       0.72    0.68

# %%
view1[view1.data_eval=='MiraBestNOHYBRID'].round(2)
# Out:
#             data_eval normalisation aggregation  accuracy   auc    f1  \
# 427  MiraBestNOHYBRID    range_norm          ft      0.84  0.92  0.84
# 433  MiraBestNOHYBRID    range_norm          ft      0.84  0.90  0.84
# 440  MiraBestNOHYBRID    range_norm          ft      0.69  0.72  0.67
#
#      precision  recall
# 427       0.86    0.84
# 433       0.84    0.84
# 440       0.74    0.69

# %%
view1[view1.data_eval=='MiraBestNOHYBRID'].groupby(['normalisation']).mean().round(2)
# Out:
#                accuracy   auc    f1  precision  recall
# normalisation
# range_norm         0.79  0.84  0.79       0.81    0.79

# %% [markdown]
# # Experiment 2 Results:

# %%
exp2 = df.loc[df.date=='0709Exp2'].copy()
exp2['normalisation']=exp2.model.str.split('-').str[1]
exp2['aggregation']=exp2.model.str.split('-').str[-3].str[11:]
exp2['f1']=(exp2.frif1+exp2.friif1)/2
exp2['precision']=(exp2.friprecision+exp2.friiprecision)/2
exp2['recall']=(exp2.frirecall+exp2.friirecall)/2
view2 = exp2[['data_eval', 
              'normalisation', 
              'aggregation',
              'accuracy', 
              'auc',
              'frif1','friif1',
              'friprecision','friiprecision',
              'frirecall','friirecall'
              #'f1',
              #'precision',
              #'recall'
             ]]
view2.sort_values(by=['aggregation','normalisation'],ascending=False).head(20).round(2)
# Out:
#             data_eval  normalisation aggregation  accuracy   auc  frif1  \
# 575     MiraBestNOUNC  std_mean_norm        mean      0.77  0.77   0.74
# 134          FRDEEP-F  std_mean_norm        mean      0.74  0.73   0.67
# 428  MiraBestNOHYBRID  std_mean_norm        mean      0.72  0.72   0.68
# 281    MiraBestHYBRID  std_mean_norm        mean      0.72  0.72   0.68
# 584     MiraBestNOUNC        softmax        mean      0.93  0.98   0.92
# 290    MiraBestHYBRID        softmax        mean      0.85  0.92   0.84
# 437  MiraBestNOHYBRID        softmax        mean      0.85  0.92   0.83
# 143          FRDEEP-F        softmax        mean      0.75  0.88   0.74
# 570     MiraBestNOUNC        sigmoid        mean      0.92  0.92   0.91
# 276    MiraBestHYBRID        sigmoid        mean      0.84  0.84   0.82
# 423  MiraBestNOHYBRID        sigmoid        mean      0.84  0.84   0.82
# 129          FRDEEP-F        sigmoid        mean      0.82  0.83   0.79
# 583     MiraBestNOUNC     range_norm        mean      0.86  0.89   0.84
# 289    MiraBestHYBRID     range_norm        mean      0.80  0.85   0.78
# 436  MiraBestNOHYBRID     range_norm        mean      0.80  0.85   0.78
# 142          FRDEEP-F     range_norm        mean      0.72  0.81   0.70
# 141          FRDEEP-F  std_mean_norm          ft      0.75  0.76   0.71
# 582     MiraBestNOUNC  std_mean_norm          ft      0.69  0.69   0.66
# 288    MiraBestHYBRID  std_mean_norm          ft      0.67  0.67   0.65
# 435  MiraBestNOHYBRID  std_mean_norm          ft      0.66  0.67   0.65
#
#      friif1  friprecision  friiprecision  frirecall  friirecall
# 575    0.79          0.79           0.75       0.69        0.84
# 134    0.78          0.75           0.73       0.60        0.84
# 428    0.75          0.77           0.69       0.61        0.82
# 281    0.75          0.76           0.69       0.61        0.82
# 584    0.93          0.97           0.89       0.87        0.98
# 290    0.86          0.90           0.82       0.78        0.92
# 437    0.86          0.90           0.82       0.78        0.92
# 143    0.75          0.68           0.84       0.83        0.69
# 570    0.93          0.97           0.88       0.85        0.98
# 276    0.85          0.90           0.80       0.75        0.92
# 423    0.85          0.89           0.80       0.75        0.92
# 129    0.85          0.85           0.81       0.73        0.90
# 583    0.87          0.89           0.84       0.80        0.91
# 289    0.82          0.84           0.78       0.73        0.87
# 436    0.82          0.84           0.77       0.73        0.87
# 142    0.73          0.65           0.78       0.76        0.69
# 141    0.78          0.73           0.76       0.68        0.80
# 582    0.72          0.69           0.70       0.64        0.74
# 288    0.68          0.66           0.67       0.64        0.69
# 435    0.68          0.66           0.67       0.64        0.69

# %%
view2[view2.data_eval=='MiraBestNOHYBRID'][view2.normalisation=='range_norm'].round(2)
# Out:
# /usr/local/anaconda-python-3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             data_eval normalisation aggregation  accuracy   auc  frif1  \
# 422  MiraBestNOHYBRID    range_norm    deep_sup      0.84  0.91   0.82
# 425  MiraBestNOHYBRID    range_norm          ft      0.83  0.87   0.81
# 434  MiraBestNOHYBRID    range_norm      concat      0.82  0.87   0.81
# 436  MiraBestNOHYBRID    range_norm        mean      0.80  0.85   0.78
#
#      friif1  friprecision  friiprecision  frirecall  friirecall
# 422    0.85          0.86           0.82       0.80        0.87
# 425    0.84          0.85           0.80       0.77        0.88
# 434    0.83          0.83           0.81       0.79        0.85
# 436    0.82          0.84           0.77       0.73        0.87

# %%
view2[view2.data_eval=='MiraBestNOHYBRID'].sort_values(by=['aggregation','normalisation'],ascending=False).round(2)
# Out:
#             data_eval  normalisation aggregation  accuracy   auc  frif1  \
# 428  MiraBestNOHYBRID  std_mean_norm        mean      0.72  0.72   0.68
# 437  MiraBestNOHYBRID        softmax        mean      0.85  0.92   0.83
# 423  MiraBestNOHYBRID        sigmoid        mean      0.84  0.84   0.82
# 436  MiraBestNOHYBRID     range_norm        mean      0.80  0.85   0.78
# 435  MiraBestNOHYBRID  std_mean_norm          ft      0.66  0.67   0.65
# 438  MiraBestNOHYBRID        softmax          ft      0.87  0.93   0.86
# 430  MiraBestNOHYBRID        sigmoid          ft      0.87  0.92   0.86
# 425  MiraBestNOHYBRID     range_norm          ft      0.83  0.87   0.81
# 426  MiraBestNOHYBRID  std_mean_norm    deep_sup      0.63  0.64   0.66
# 421  MiraBestNOHYBRID        softmax    deep_sup      0.85  0.92   0.85
# 424  MiraBestNOHYBRID        sigmoid    deep_sup      0.80  0.81   0.81
# 422  MiraBestNOHYBRID     range_norm    deep_sup      0.84  0.91   0.82
# 439  MiraBestNOHYBRID  std_mean_norm      concat      0.80  0.80   0.77
# 429  MiraBestNOHYBRID        softmax      concat      0.87  0.93   0.86
# 432  MiraBestNOHYBRID        sigmoid      concat      0.84  0.84   0.83
# 434  MiraBestNOHYBRID     range_norm      concat      0.82  0.87   0.81
#
#      friif1  friprecision  friiprecision  frirecall  friirecall
# 428    0.75          0.77           0.69       0.61        0.82
# 437    0.86          0.90           0.82       0.78        0.92
# 423    0.85          0.89           0.80       0.75        0.92
# 436    0.82          0.84           0.77       0.73        0.87
# 435    0.68          0.66           0.67       0.64        0.69
# 438    0.88          0.91           0.84       0.80        0.93
# 430    0.88          0.90           0.84       0.82        0.91
# 425    0.84          0.85           0.80       0.77        0.88
# 426    0.60          0.60           0.69       0.74        0.53
# 421    0.86          0.85           0.86       0.85        0.86
# 424    0.80          0.77           0.84       0.85        0.76
# 422    0.85          0.86           0.82       0.80        0.87
# 439    0.82          0.86           0.76       0.70        0.89
# 429    0.88          0.91           0.84       0.81        0.92
# 432    0.84          0.84           0.83       0.82        0.86
# 434    0.83          0.83           0.81       0.79        0.85

# %%
# Testset==Trainset Only:
view2[view2.data_eval=='MiraBestNOHYBRID'].groupby(['aggregation']).mean().round(2)
# Out:
#              accuracy   auc  frif1  friif1  friprecision  friiprecision  \
# aggregation
# concat           0.83  0.86   0.82    0.84          0.86           0.81
# deep_sup         0.78  0.82   0.79    0.78          0.77           0.80
# ft               0.81  0.85   0.79    0.82          0.83           0.79
# mean             0.80  0.83   0.78    0.82          0.85           0.77
#
#              frirecall  friirecall
# aggregation
# concat            0.78        0.88
# deep_sup          0.81        0.75
# ft                0.76        0.85
# mean              0.72        0.88

# %%
view2[view2.data_eval=='MiraBestNOHYBRID'].groupby(['normalisation']).mean().round(2)
# Out:
#                accuracy   auc  frif1  friif1  friprecision  friiprecision  \
# normalisation
# range_norm         0.82  0.87   0.81    0.83          0.84           0.80
# sigmoid            0.84  0.85   0.83    0.84          0.85           0.83
# softmax            0.86  0.92   0.85    0.87          0.89           0.84
# std_mean_norm      0.70  0.71   0.69    0.71          0.72           0.70
#
#                frirecall  friirecall
# normalisation
# range_norm          0.77        0.87
# sigmoid             0.81        0.86
# softmax             0.81        0.91
# std_mean_norm       0.67        0.73

# %%
view2.groupby(['data_eval']).mean().round(2)
# Out:
#                   accuracy   auc    f1  precision  recall
# data_eval
# FRDEEP-F              0.77  0.82  0.77       0.77    0.77
# MiraBestHYBRID        0.81  0.84  0.80       0.81    0.80
# MiraBestNOHYBRID      0.81  0.84  0.80       0.81    0.80
# MiraBestNOUNC         0.87  0.89  0.86       0.87    0.86

# %%
view2[view2.data_eval=='FRDEEP-F'].round(2)
# Out:
#     data_eval  normalisation aggregation  accuracy   auc    f1  precision  \
# 127  FRDEEP-F        softmax    deep_sup      0.84  0.93  0.83       0.83
# 129  FRDEEP-F        sigmoid        mean      0.82  0.83  0.82       0.83
# 135  FRDEEP-F        softmax      concat      0.80  0.87  0.80       0.80
# 130  FRDEEP-F        sigmoid    deep_sup      0.80  0.80  0.79       0.79
# 145  FRDEEP-F  std_mean_norm      concat      0.79  0.78  0.78       0.80
# 140  FRDEEP-F     range_norm      concat      0.78  0.81  0.77       0.77
# 138  FRDEEP-F        sigmoid      concat      0.77  0.77  0.77       0.77
# 144  FRDEEP-F        softmax          ft      0.77  0.86  0.77       0.77
# 128  FRDEEP-F     range_norm    deep_sup      0.76  0.83  0.76       0.76
# 136  FRDEEP-F        sigmoid          ft      0.75  0.81  0.75       0.75
# 143  FRDEEP-F        softmax        mean      0.75  0.88  0.75       0.76
# 141  FRDEEP-F  std_mean_norm          ft      0.75  0.76  0.74       0.75
# 131  FRDEEP-F     range_norm          ft      0.75  0.85  0.75       0.76
# 134  FRDEEP-F  std_mean_norm        mean      0.74  0.73  0.73       0.74
# 132  FRDEEP-F  std_mean_norm    deep_sup      0.74  0.75  0.74       0.76
# 142  FRDEEP-F     range_norm        mean      0.72  0.81  0.72       0.72
#
#      recall
# 127    0.84
# 129    0.81
# 135    0.80
# 130    0.79
# 145    0.77
# 140    0.77
# 138    0.77
# 144    0.77
# 128    0.76
# 136    0.75
# 143    0.76
# 141    0.74
# 131    0.76
# 134    0.72
# 132    0.75
# 142    0.72

# %%
view2[view2.data_eval=='MiraBestNOUNC'].round(2)
# Out:
#          data_eval  normalisation aggregation  accuracy   auc    f1  \
# 576  MiraBestNOUNC        softmax      concat      0.94  0.99  0.94
# 577  MiraBestNOUNC        sigmoid          ft      0.94  0.98  0.94
# 585  MiraBestNOUNC        softmax          ft      0.93  0.98  0.92
# 584  MiraBestNOUNC        softmax        mean      0.93  0.98  0.92
# 568  MiraBestNOUNC        softmax    deep_sup      0.92  0.98  0.92
# 569  MiraBestNOUNC     range_norm    deep_sup      0.92  0.98  0.92
# 570  MiraBestNOUNC        sigmoid        mean      0.92  0.92  0.92
# 579  MiraBestNOUNC        sigmoid      concat      0.90  0.90  0.90
# 572  MiraBestNOUNC     range_norm          ft      0.88  0.93  0.88
# 581  MiraBestNOUNC     range_norm      concat      0.88  0.93  0.88
# 571  MiraBestNOUNC        sigmoid    deep_sup      0.86  0.87  0.86
# 586  MiraBestNOUNC  std_mean_norm      concat      0.86  0.86  0.86
# 583  MiraBestNOUNC     range_norm        mean      0.86  0.89  0.86
# 575  MiraBestNOUNC  std_mean_norm        mean      0.77  0.77  0.77
# 582  MiraBestNOUNC  std_mean_norm          ft      0.69  0.69  0.69
# 573  MiraBestNOUNC  std_mean_norm    deep_sup      0.66  0.67  0.66
#
#      precision  recall
# 576       0.94    0.94
# 577       0.94    0.93
# 585       0.93    0.92
# 584       0.93    0.92
# 568       0.92    0.92
# 569       0.92    0.92
# 570       0.93    0.91
# 579       0.90    0.90
# 572       0.89    0.88
# 581       0.88    0.88
# 571       0.87    0.87
# 586       0.87    0.86
# 583       0.86    0.86
# 575       0.77    0.77
# 582       0.69    0.69
# 573       0.67    0.67
