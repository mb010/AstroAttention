# %% [markdown]
# This script mostly follows [the standard CIFAR10 Pytorch example](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html). It extracts grey scale images from the dataset.
#
# The steps are:
#
# 1. Load and normalizing the FRDEEP-F training and test datasets using torchvision
# 2. Define a Convolutional Neural Network
# 3. Define a loss function
# 4. Train the network on the training data
# 5. Test the network on the test data

# %% [markdown]
# First import some standard python libraries for plotting stuff and handling arrays:

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import PIL

# %% [markdown]
# Then import the pytorch, torchvision and torchsummary libraries:

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torchsummary import summary
from torch.utils.data import SubsetRandomSampler

# %% [markdown]
# Then import the pytorch neural network stuff:

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# Then import the oprimization library from pytorch:

# %%
import torch.optim as optim

# %%
from networks.sononet_grid_attention import sononet_grid_attention as sononet2

# %% [markdown]
# The output of torchvision datasets are PILImage images of range [0, 1]. We transform them to Tensors of normalized range [-1, 1].

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(), # randomly flip and rotate
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# %% [markdown]
# Load in the training and test datasets. The first time you do this it will download the data to your working directory, but once the data is there it will just use it without repeating the download.

# %%
# choose the training and test datasets
trainset = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform)
testset = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform)
bsize=16
batch_size_train = bsize
batch_size_test = bsize
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# percentage of training set to use as validation
valid_size = 0.2

# %%
# obtain training indices that will be used for validation
num_train = len(trainset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %%
# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
validset = datasets.CIFAR10('data', train=True, download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %% [markdown]
# There are two classes in this dataset: FRI and FRII:

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size_train, sampler=train_sampler, num_workers=2)
validloader = torch.utils.data.DataLoader(validset, batch_size=batch_size_train, sampler=valid_sampler, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size_test, shuffle=True, num_workers=2)

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# A little function to display images nicely:

# %%
def imshow(img):
    # unnormalize
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %% [markdown]
# Take a look at some randomly selected samples to see how they appear:

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# %%
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size_train)))
# Out:
#  frog  ship  bird  deer   dog  deer  frog truck airplane airplane airplane  deer automobile horse  bird  bird

# %% [markdown]
# Define a neural network that takes greyscale images as input:

# %%
net = sononet2(feature_scale=4, n_classes=10, in_channels=3)
net.cuda()
summary(net,(3,32,32))
# Out:
# /home/clumsybell/attenv/lib/python3.6/site-packages/AttentionGatedNetworks-1.0-py3.6.egg/models/networks_other.py:42: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   init.kaiming_normal(m.weight.data, a=0, mode='fan_in')
# /home/clumsybell/attenv/lib/python3.6/site-packages/AttentionGatedNetworks-1.0-py3.6.egg/models/networks_other.py:46: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   init.normal(m.weight.data, 1.0, 0.02)
# /home/clumsybell/attenv/lib/python3.6/site-packages/AttentionGatedNetworks-1.0-py3.6.egg/models/networks_other.py:47: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   init.constant(m.bias.data, 0.0)
# /home/clumsybell/attenv/lib/python3.6/site-packages/AttentionGatedNetworks-1.0-py3.6.egg/models/layers/grid_attention_layer.py:269: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(self.psi.bias.data, 10.0)
# /home/clumsybell/attenv/lib/python3.6/site-packages/torch/nn/functional.py:2390: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /home/clumsybell/attenv/lib/python3.6/site-packages/torch/nn/functional.py:2479: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#             Conv2d-4           [-1, 16, 32, 32]           2,320
#        BatchNorm2d-5           [-1, 16, 32, 32]              32
#               ReLU-6           [-1, 16, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]           2,320
#        BatchNorm2d-8           [-1, 16, 32, 32]              32
#               ReLU-9           [-1, 16, 32, 32]               0
#         unetConv2-10           [-1, 16, 32, 32]               0
#         MaxPool2d-11           [-1, 16, 16, 16]               0
#            Conv2d-12           [-1, 32, 16, 16]           4,640
#       BatchNorm2d-13           [-1, 32, 16, 16]              64
#              ReLU-14           [-1, 32, 16, 16]               0
#            Conv2d-15           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-16           [-1, 32, 16, 16]              64
#              ReLU-17           [-1, 32, 16, 16]               0
#            Conv2d-18           [-1, 32, 16, 16]           9,248
#       BatchNorm2d-19           [-1, 32, 16, 16]              64
#              ReLU-20           [-1, 32, 16, 16]               0
#         unetConv2-21           [-1, 32, 16, 16]               0
#         MaxPool2d-22             [-1, 32, 8, 8]               0
#            Conv2d-23             [-1, 64, 8, 8]          18,496
#       BatchNorm2d-24             [-1, 64, 8, 8]             128
#              ReLU-25             [-1, 64, 8, 8]               0
#            Conv2d-26             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-27             [-1, 64, 8, 8]             128
#              ReLU-28             [-1, 64, 8, 8]               0
#            Conv2d-29             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-30             [-1, 64, 8, 8]             128
#              ReLU-31             [-1, 64, 8, 8]               0
#         unetConv2-32             [-1, 64, 8, 8]               0
#         MaxPool2d-33             [-1, 64, 4, 4]               0
#            Conv2d-34            [-1, 128, 4, 4]          73,856
#       BatchNorm2d-35            [-1, 128, 4, 4]             256
#              ReLU-36            [-1, 128, 4, 4]               0
#            Conv2d-37            [-1, 128, 4, 4]         147,584
#       BatchNorm2d-38            [-1, 128, 4, 4]             256
#              ReLU-39            [-1, 128, 4, 4]               0
#         unetConv2-40            [-1, 128, 4, 4]               0
#         MaxPool2d-41            [-1, 128, 2, 2]               0
#            Conv2d-42            [-1, 128, 2, 2]         147,584
#       BatchNorm2d-43            [-1, 128, 2, 2]             256
#              ReLU-44            [-1, 128, 2, 2]               0
#            Conv2d-45            [-1, 128, 2, 2]         147,584
#       BatchNorm2d-46            [-1, 128, 2, 2]             256
#              ReLU-47            [-1, 128, 2, 2]               0
#         unetConv2-48            [-1, 128, 2, 2]               0
#            Conv2d-49            [-1, 128, 8, 8]           8,192
#            Conv2d-50            [-1, 128, 2, 2]          16,384
#            Conv2d-51              [-1, 1, 8, 8]             129
# GridAttentionBlock2D_TORR-52  [[-1, 64, 8, 8], [-1, 1, 8, 8]]               0
#            Conv2d-53            [-1, 128, 4, 4]          16,384
#            Conv2d-54            [-1, 128, 2, 2]          16,384
#            Conv2d-55              [-1, 1, 4, 4]             129
# GridAttentionBlock2D_TORR-56  [[-1, 128, 4, 4], [-1, 1, 4, 4]]               0
#            Linear-57                   [-1, 10]           3,210
# ================================================================
# Total params: 699,692
# Trainable params: 699,692
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.22
# Params size (MB): 2.67
# Estimated Total Size (MB): 2.90
# ----------------------------------------------------------------

# %% [markdown]
# We'll use Classification Cross-Entropy loss and Adagrad with momentum for optimization:

# %%
vi = nn.CrossEntropyLoss()
optimizer = optim.Adagrad(net.parameters(), lr=0.001)

# %%
ckpt_name = f'model_sononet_CIFAR10_bayesian.pt'
ckpt_name
# Out:
# 'model_sononet_CIFAR10_bayesian.pt'

# %% [markdown]
# Run 10 epochs of training:

# %%
# %%time

valid_loss_min = np.Inf # track change in validation loss
batch_size=bsize
outputs = 10 # number of classes
inputs = 3 # number of channels
resume = False
n_epochs = 150
lr = 0.001
weight_decay = 0.0005
num_samples = 1
beta_type = "Blundell"
resize=32 # dimension of image
use_cuda = True

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    m = math.ceil(len(trainset) / batch_size)
    
    ###################
    # train the model #
    ###################
    net.train()
    for batch_idx, (data, target) in enumerate(trainloader):
        # move tensors to GPU if CUDA is available
        
        data = data.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
        target = target.repeat(num_samples)
        if use_cuda:
            data, target = data.cuda(), target.cuda()
            
        if beta_type is "Blundell":
            beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
        elif beta_type is "Soenderby":
            beta = min(epoch / (num_epochs // 4), 1)
        elif beta_type is "Standard":
            beta = 1 / m
        else:
            beta = 0
            
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        #print("here 1:",data.shape)
        
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = net.forward(data)
        #print("here 2:",outputs.shape)
        
        # calculate the batch loss
        #loss = vi(output, target, kl, beta)
        loss = vi(outputs, target)
        #print("here 3:",loss)
        
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += (loss.item()*data.size(0)) / num_samples
        # print("here 4:",train_loss)
        
    ######################    
    # validate the model #
    ######################
    net.eval()
    for batch_idx, (data, target) in enumerate(validloader):
        data = data.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
        target = target.repeat(num_samples)
        # move tensors to GPU if CUDA is available
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = net.forward(data)
        # calculate the batch loss
        #loss = vi(output, target, kl, beta)
        loss = vi(outputs, target)
        # update average validation loss 
        valid_loss += (loss.item()*data.size(0)) / num_samples
        
    # calculate average losses
    train_loss = train_loss/(len(trainloader.dataset) * (1-valid_size))
    valid_loss = valid_loss/(len(validloader.dataset) * valid_size)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(net.state_dict(), ckpt_name)
        valid_loss_min = valid_loss

print('Finished Training')
# Out:
# Epoch: 1 	Training Loss: 1.684108 	Validation Loss: 1.486826
# Validation loss decreased (inf --> 1.486826).  Saving model ...
# Epoch: 2 	Training Loss: 1.509709 	Validation Loss: 1.411266
# Validation loss decreased (1.486826 --> 1.411266).  Saving model ...
# Epoch: 3 	Training Loss: 1.448361 	Validation Loss: 1.361901
# Validation loss decreased (1.411266 --> 1.361901).  Saving model ...
# Epoch: 4 	Training Loss: 1.410923 	Validation Loss: 1.324901
# Validation loss decreased (1.361901 --> 1.324901).  Saving model ...
# Epoch: 5 	Training Loss: 1.384052 	Validation Loss: 1.299422
# Validation loss decreased (1.324901 --> 1.299422).  Saving model ...
# Epoch: 6 	Training Loss: 1.358485 	Validation Loss: 1.274025
# Validation loss decreased (1.299422 --> 1.274025).  Saving model ...
# Epoch: 7 	Training Loss: 1.337218 	Validation Loss: 1.260640
# Validation loss decreased (1.274025 --> 1.260640).  Saving model ...
# Epoch: 8 	Training Loss: 1.319081 	Validation Loss: 1.246848
# Validation loss decreased (1.260640 --> 1.246848).  Saving model ...
# Epoch: 9 	Training Loss: 1.306620 	Validation Loss: 1.235039
# Validation loss decreased (1.246848 --> 1.235039).  Saving model ...
# Epoch: 10 	Training Loss: 1.291858 	Validation Loss: 1.218957
# Validation loss decreased (1.235039 --> 1.218957).  Saving model ...
# Epoch: 11 	Training Loss: 1.281037 	Validation Loss: 1.204095
# Validation loss decreased (1.218957 --> 1.204095).  Saving model ...
# Epoch: 12 	Training Loss: 1.258529 	Validation Loss: 1.196471
# Validation loss decreased (1.204095 --> 1.196471).  Saving model ...
# Epoch: 13 	Training Loss: 1.255606 	Validation Loss: 1.191936
# Validation loss decreased (1.196471 --> 1.191936).  Saving model ...
# Epoch: 14 	Training Loss: 1.237372 	Validation Loss: 1.182543
# Validation loss decreased (1.191936 --> 1.182543).  Saving model ...
# Epoch: 15 	Training Loss: 1.232815 	Validation Loss: 1.175306
# Validation loss decreased (1.182543 --> 1.175306).  Saving model ...
# Epoch: 16 	Training Loss: 1.222082 	Validation Loss: 1.164214
# Validation loss decreased (1.175306 --> 1.164214).  Saving model ...
# Epoch: 17 	Training Loss: 1.214685 	Validation Loss: 1.160449
# Validation loss decreased (1.164214 --> 1.160449).  Saving model ...
# Epoch: 18 	Training Loss: 1.206790 	Validation Loss: 1.146334
# Validation loss decreased (1.160449 --> 1.146334).  Saving model ...
# Epoch: 19 	Training Loss: 1.194126 	Validation Loss: 1.144901
# Validation loss decreased (1.146334 --> 1.144901).  Saving model ...
# Epoch: 20 	Training Loss: 1.188498 	Validation Loss: 1.137736
# Validation loss decreased (1.144901 --> 1.137736).  Saving model ...
# Epoch: 21 	Training Loss: 1.181901 	Validation Loss: 1.137336
# Validation loss decreased (1.137736 --> 1.137336).  Saving model ...
# Epoch: 22 	Training Loss: 1.170698 	Validation Loss: 1.133349
# Validation loss decreased (1.137336 --> 1.133349).  Saving model ...
# Epoch: 23 	Training Loss: 1.167341 	Validation Loss: 1.118605
# Validation loss decreased (1.133349 --> 1.118605).  Saving model ...
# Epoch: 24 	Training Loss: 1.164127 	Validation Loss: 1.112419
# Validation loss decreased (1.118605 --> 1.112419).  Saving model ...
# Epoch: 25 	Training Loss: 1.154810 	Validation Loss: 1.116244
# Epoch: 26 	Training Loss: 1.154748 	Validation Loss: 1.116414
# Epoch: 27 	Training Loss: 1.141261 	Validation Loss: 1.100464
# Validation loss decreased (1.112419 --> 1.100464).  Saving model ...
# Epoch: 28 	Training Loss: 1.134548 	Validation Loss: 1.092978
# Validation loss decreased (1.100464 --> 1.092978).  Saving model ...
# Epoch: 29 	Training Loss: 1.135484 	Validation Loss: 1.093046
# Epoch: 30 	Training Loss: 1.131690 	Validation Loss: 1.092101
# Validation loss decreased (1.092978 --> 1.092101).  Saving model ...
# Epoch: 31 	Training Loss: 1.122011 	Validation Loss: 1.088364
# Validation loss decreased (1.092101 --> 1.088364).  Saving model ...
# Epoch: 32 	Training Loss: 1.119723 	Validation Loss: 1.072965
# Validation loss decreased (1.088364 --> 1.072965).  Saving model ...
# Epoch: 33 	Training Loss: 1.118459 	Validation Loss: 1.083889
# Epoch: 34 	Training Loss: 1.109976 	Validation Loss: 1.070327
# Validation loss decreased (1.072965 --> 1.070327).  Saving model ...
# Epoch: 35 	Training Loss: 1.101670 	Validation Loss: 1.071833
# Epoch: 36 	Training Loss: 1.098336 	Validation Loss: 1.071596
# Epoch: 37 	Training Loss: 1.093960 	Validation Loss: 1.063924
# Validation loss decreased (1.070327 --> 1.063924).  Saving model ...
# Epoch: 38 	Training Loss: 1.097956 	Validation Loss: 1.057861
# Validation loss decreased (1.063924 --> 1.057861).  Saving model ...
# Epoch: 39 	Training Loss: 1.088616 	Validation Loss: 1.068459
# Epoch: 40 	Training Loss: 1.080280 	Validation Loss: 1.055426
# Validation loss decreased (1.057861 --> 1.055426).  Saving model ...
# Epoch: 41 	Training Loss: 1.082244 	Validation Loss: 1.057238
# Epoch: 42 	Training Loss: 1.075297 	Validation Loss: 1.048383
# Validation loss decreased (1.055426 --> 1.048383).  Saving model ...
# Epoch: 43 	Training Loss: 1.077574 	Validation Loss: 1.047082
# Validation loss decreased (1.048383 --> 1.047082).  Saving model ...
# Epoch: 44 	Training Loss: 1.068602 	Validation Loss: 1.049456
# Epoch: 45 	Training Loss: 1.064997 	Validation Loss: 1.041246
# Validation loss decreased (1.047082 --> 1.041246).  Saving model ...
# Epoch: 46 	Training Loss: 1.063659 	Validation Loss: 1.037672
# Validation loss decreased (1.041246 --> 1.037672).  Saving model ...
# Epoch: 47 	Training Loss: 1.059052 	Validation Loss: 1.034105
# Validation loss decreased (1.037672 --> 1.034105).  Saving model ...
# Epoch: 48 	Training Loss: 1.055723 	Validation Loss: 1.036481
# Epoch: 49 	Training Loss: 1.053849 	Validation Loss: 1.033809
# Validation loss decreased (1.034105 --> 1.033809).  Saving model ...
# Epoch: 50 	Training Loss: 1.050706 	Validation Loss: 1.034992
# Epoch: 51 	Training Loss: 1.041791 	Validation Loss: 1.020466
# Validation loss decreased (1.033809 --> 1.020466).  Saving model ...
# Epoch: 52 	Training Loss: 1.043580 	Validation Loss: 1.018905
# Validation loss decreased (1.020466 --> 1.018905).  Saving model ...
# Epoch: 53 	Training Loss: 1.038628 	Validation Loss: 1.027562
# Epoch: 54 	Training Loss: 1.035455 	Validation Loss: 1.020680
# Epoch: 55 	Training Loss: 1.034179 	Validation Loss: 1.015524
# Validation loss decreased (1.018905 --> 1.015524).  Saving model ...
# Epoch: 56 	Training Loss: 1.029858 	Validation Loss: 1.018381
# Epoch: 57 	Training Loss: 1.030010 	Validation Loss: 1.011840
# Validation loss decreased (1.015524 --> 1.011840).  Saving model ...
# Epoch: 58 	Training Loss: 1.023777 	Validation Loss: 1.018685
# Epoch: 59 	Training Loss: 1.021427 	Validation Loss: 1.007185
# Validation loss decreased (1.011840 --> 1.007185).  Saving model ...
# Epoch: 60 	Training Loss: 1.022213 	Validation Loss: 0.999877
# Validation loss decreased (1.007185 --> 0.999877).  Saving model ...
# Epoch: 61 	Training Loss: 1.020881 	Validation Loss: 1.007329
# Epoch: 62 	Training Loss: 1.014317 	Validation Loss: 1.004730
# Epoch: 63 	Training Loss: 1.006785 	Validation Loss: 1.008258
# Epoch: 64 	Training Loss: 1.005012 	Validation Loss: 1.002768
# Epoch: 65 	Training Loss: 1.001230 	Validation Loss: 1.002619
# Epoch: 66 	Training Loss: 1.004348 	Validation Loss: 1.002915
# Epoch: 67 	Training Loss: 0.999006 	Validation Loss: 0.998227
# Validation loss decreased (0.999877 --> 0.998227).  Saving model ...
# Epoch: 68 	Training Loss: 0.996337 	Validation Loss: 0.997648
# Validation loss decreased (0.998227 --> 0.997648).  Saving model ...
# Epoch: 69 	Training Loss: 0.998775 	Validation Loss: 0.990842
# Validation loss decreased (0.997648 --> 0.990842).  Saving model ...
# Epoch: 70 	Training Loss: 0.991733 	Validation Loss: 0.989776
# Validation loss decreased (0.990842 --> 0.989776).  Saving model ...
# Epoch: 71 	Training Loss: 0.989734 	Validation Loss: 0.992715
# Epoch: 72 	Training Loss: 0.989376 	Validation Loss: 0.987540
# Validation loss decreased (0.989776 --> 0.987540).  Saving model ...
# Epoch: 73 	Training Loss: 0.989236 	Validation Loss: 0.992084
# Epoch: 74 	Training Loss: 0.982546 	Validation Loss: 0.988805
# Epoch: 75 	Training Loss: 0.979733 	Validation Loss: 0.978635
# Validation loss decreased (0.987540 --> 0.978635).  Saving model ...
# Epoch: 76 	Training Loss: 0.979174 	Validation Loss: 0.966194
# Validation loss decreased (0.978635 --> 0.966194).  Saving model ...
# Epoch: 77 	Training Loss: 0.974283 	Validation Loss: 0.984246
# Epoch: 78 	Training Loss: 0.971581 	Validation Loss: 0.987256
# Epoch: 79 	Training Loss: 0.970855 	Validation Loss: 0.984058
# Epoch: 80 	Training Loss: 0.972852 	Validation Loss: 0.984596
# Epoch: 81 	Training Loss: 0.966639 	Validation Loss: 0.974488
# Epoch: 82 	Training Loss: 0.967053 	Validation Loss: 0.982028
# Epoch: 83 	Training Loss: 0.963386 	Validation Loss: 0.974709
# Epoch: 84 	Training Loss: 0.963466 	Validation Loss: 0.967735
# Epoch: 85 	Training Loss: 0.958298 	Validation Loss: 0.964907
# Validation loss decreased (0.966194 --> 0.964907).  Saving model ...
# Epoch: 86 	Training Loss: 0.962036 	Validation Loss: 0.966585
# Epoch: 87 	Training Loss: 0.953763 	Validation Loss: 0.961632
# Validation loss decreased (0.964907 --> 0.961632).  Saving model ...
# Epoch: 88 	Training Loss: 0.954163 	Validation Loss: 0.968927
# Epoch: 89 	Training Loss: 0.954805 	Validation Loss: 0.957751
# Validation loss decreased (0.961632 --> 0.957751).  Saving model ...
# Epoch: 90 	Training Loss: 0.950469 	Validation Loss: 0.958139
# Epoch: 91 	Training Loss: 0.948299 	Validation Loss: 0.965002
# Epoch: 92 	Training Loss: 0.945768 	Validation Loss: 0.960785
# Epoch: 93 	Training Loss: 0.943657 	Validation Loss: 0.955760
# Validation loss decreased (0.957751 --> 0.955760).  Saving model ...
# Epoch: 94 	Training Loss: 0.939691 	Validation Loss: 0.956338
# Epoch: 95 	Training Loss: 0.941071 	Validation Loss: 0.950339
# Validation loss decreased (0.955760 --> 0.950339).  Saving model ...
# Epoch: 96 	Training Loss: 0.940388 	Validation Loss: 0.957411
# Epoch: 97 	Training Loss: 0.938140 	Validation Loss: 0.949055
# Validation loss decreased (0.950339 --> 0.949055).  Saving model ...
# Epoch: 98 	Training Loss: 0.934078 	Validation Loss: 0.954000
# Epoch: 99 	Training Loss: 0.935679 	Validation Loss: 0.946929
# Validation loss decreased (0.949055 --> 0.946929).  Saving model ...
# Epoch: 100 	Training Loss: 0.930417 	Validation Loss: 0.947414
# Epoch: 101 	Training Loss: 0.927261 	Validation Loss: 0.951407
# Epoch: 102 	Training Loss: 0.932918 	Validation Loss: 0.949332
# Epoch: 103 	Training Loss: 0.926327 	Validation Loss: 0.943214
# Validation loss decreased (0.946929 --> 0.943214).  Saving model ...
# Epoch: 104 	Training Loss: 0.930211 	Validation Loss: 0.944327
# Epoch: 105 	Training Loss: 0.925928 	Validation Loss: 0.943540
# Epoch: 106 	Training Loss: 0.922915 	Validation Loss: 0.941279
# Validation loss decreased (0.943214 --> 0.941279).  Saving model ...
# Epoch: 107 	Training Loss: 0.923375 	Validation Loss: 0.943328
# Epoch: 108 	Training Loss: 0.921751 	Validation Loss: 0.938264
# Validation loss decreased (0.941279 --> 0.938264).  Saving model ...
# Epoch: 109 	Training Loss: 0.921035 	Validation Loss: 0.938898
# Epoch: 110 	Training Loss: 0.918588 	Validation Loss: 0.933152
# Validation loss decreased (0.938264 --> 0.933152).  Saving model ...
# Epoch: 111 	Training Loss: 0.912444 	Validation Loss: 0.946370
# Epoch: 112 	Training Loss: 0.916147 	Validation Loss: 0.932185
# Validation loss decreased (0.933152 --> 0.932185).  Saving model ...
# Epoch: 113 	Training Loss: 0.913879 	Validation Loss: 0.939188
# Epoch: 114 	Training Loss: 0.910644 	Validation Loss: 0.941623
# Epoch: 115 	Training Loss: 0.904000 	Validation Loss: 0.931860
# Validation loss decreased (0.932185 --> 0.931860).  Saving model ...
# Epoch: 116 	Training Loss: 0.907030 	Validation Loss: 0.935266
# Epoch: 117 	Training Loss: 0.905078 	Validation Loss: 0.940097
# Epoch: 118 	Training Loss: 0.908416 	Validation Loss: 0.932995
# Epoch: 119 	Training Loss: 0.902627 	Validation Loss: 0.929721
# Validation loss decreased (0.931860 --> 0.929721).  Saving model ...
# Epoch: 120 	Training Loss: 0.904776 	Validation Loss: 0.933487
# Epoch: 121 	Training Loss: 0.897879 	Validation Loss: 0.933285
# Epoch: 122 	Training Loss: 0.897968 	Validation Loss: 0.929983
# Epoch: 123 	Training Loss: 0.899101 	Validation Loss: 0.928725
# Validation loss decreased (0.929721 --> 0.928725).  Saving model ...
# Epoch: 124 	Training Loss: 0.899361 	Validation Loss: 0.925716
# Validation loss decreased (0.928725 --> 0.925716).  Saving model ...
# Epoch: 125 	Training Loss: 0.892087 	Validation Loss: 0.922475
# Validation loss decreased (0.925716 --> 0.922475).  Saving model ...
# Epoch: 126 	Training Loss: 0.891736 	Validation Loss: 0.924218
# Epoch: 127 	Training Loss: 0.892989 	Validation Loss: 0.932072
# Epoch: 128 	Training Loss: 0.888392 	Validation Loss: 0.921185
# Validation loss decreased (0.922475 --> 0.921185).  Saving model ...
# Epoch: 129 	Training Loss: 0.888075 	Validation Loss: 0.926876
# Epoch: 130 	Training Loss: 0.888569 	Validation Loss: 0.923712
# Epoch: 131 	Training Loss: 0.885090 	Validation Loss: 0.919548
# Validation loss decreased (0.921185 --> 0.919548).  Saving model ...
# Epoch: 132 	Training Loss: 0.887002 	Validation Loss: 0.921822
# Epoch: 133 	Training Loss: 0.882852 	Validation Loss: 0.917163
# Validation loss decreased (0.919548 --> 0.917163).  Saving model ...
# Epoch: 134 	Training Loss: 0.881012 	Validation Loss: 0.908308
# Validation loss decreased (0.917163 --> 0.908308).  Saving model ...
# Epoch: 135 	Training Loss: 0.881697 	Validation Loss: 0.916921
# Epoch: 136 	Training Loss: 0.877110 	Validation Loss: 0.918213
# Epoch: 137 	Training Loss: 0.878402 	Validation Loss: 0.926447
# Epoch: 138 	Training Loss: 0.875534 	Validation Loss: 0.913589
# Epoch: 139 	Training Loss: 0.880703 	Validation Loss: 0.909495
# Epoch: 140 	Training Loss: 0.878371 	Validation Loss: 0.905675
# Validation loss decreased (0.908308 --> 0.905675).  Saving model ...
# Epoch: 141 	Training Loss: 0.873755 	Validation Loss: 0.915593
# Epoch: 142 	Training Loss: 0.875235 	Validation Loss: 0.915992
# Epoch: 143 	Training Loss: 0.869829 	Validation Loss: 0.914264
# Epoch: 144 	Training Loss: 0.867438 	Validation Loss: 0.906375
# Epoch: 145 	Training Loss: 0.868533 	Validation Loss: 0.908873
# Epoch: 146 	Training Loss: 0.866536 	Validation Loss: 0.905435
# Validation loss decreased (0.905675 --> 0.905435).  Saving model ...
# Epoch: 147 	Training Loss: 0.861985 	Validation Loss: 0.912847
# Epoch: 148 	Training Loss: 0.867870 	Validation Loss: 0.908713
# Epoch: 149 	Training Loss: 0.865710 	Validation Loss: 0.901772
# Validation loss decreased (0.905435 --> 0.901772).  Saving model ...
# Epoch: 150 	Training Loss: 0.863829 	Validation Loss: 0.913203
# Finished Training
# CPU times: user 2h 42min 55s, sys: 4min 33s, total: 2h 47min 28s
# Wall time: 2h 19s

# %% [markdown]
# Now we'll try out a couple of test samples just for visual kicks. First load them up and take a look at the true labels:

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# %%
# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(batch_size_test)))
# Out:
# GroundTruth:  automobile  bird   cat  frog truck   cat   cat  ship   dog  frog   cat  frog horse   dog horse   cat

# %% [markdown]
# Then see what the network predicts that they are:

# %%
outputs = net(images.cuda())

# %%
_, predicted = torch.max(outputs, 1)
print('Predicted: ', ' '.join('%5s' % classes[predicted[j]] for j in range(batch_size_test)))
# Out:
# Predicted:  truck   cat   cat  frog airplane   dog   cat  ship   dog  frog horse  frog horse   dog horse   dog

# %% [markdown]
# Now calculate the overall accuracy of the network on **all** the test images:

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net.forward(images.cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum().item()

print('Accuracy of the network on the 50 test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the 50 test images: 67 %

# %% [markdown]
# This is a imbalanced dataset, so let's take a look at the accuracy for individual classes:

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net.forward(images.cuda())
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels.cuda()).squeeze()
        for i in range(batch_size_test):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

# %%
for i in range(len(classes)):
    print('Accuracy of %5s : %2d %%' % (classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of airplane : 72 %
# Accuracy of automobile : 80 %
# Accuracy of  bird : 54 %
# Accuracy of   cat : 50 %
# Accuracy of  deer : 55 %
# Accuracy of   dog : 53 %
# Accuracy of  frog : 77 %
# Accuracy of horse : 71 %
# Accuracy of  ship : 79 %
# Accuracy of truck : 73 %

# %% [markdown]
# ----

# %% [markdown]
# These next cells are adapted from the visualise_attention and visualise_fmaps python scripts in the sononet github repo.

# %%
dataloader = torch.utils.data.DataLoader(trainset, batch_size=1, shuffle=True, num_workers=2)
dataiter = iter(dataloader)
images, labels = dataiter.next()

# %%
with torch.no_grad():
    for data in dataloader:
        images, labels = data
        outputs = net.forward(images.cuda())
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels.cuda()).squeeze()

# %%
#from scipy.misc import imresize
from skimage.transform import resize
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
def plotNNFilterOverlay(input_im, units, figure_id, interp='bilinear', colormap=cm.jet, colormap_lim=None, title='', alpha=0.8):

    filters = units.shape[2]
    fig = plt.figure(figure_id, figsize=(5,5))
    fig.clf()

    for i in range(filters):
        plt.imshow(input_im[:,:,0], interpolation=interp, cmap='gray')
        plt.imshow(units[:,:,i], interpolation=interp, cmap=colormap, alpha=alpha)
        plt.axis('off')
        plt.colorbar()
        plt.title(title, fontsize='small')
        if colormap_lim:
            plt.clim(colormap_lim[0],colormap_lim[1])

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.tight_layout()

# %%
input_img = images[0,0].numpy()
input_img = np.expand_dims(input_img, axis=2)

# %%
plotNNFilterOverlay(input_img, np.zeros_like(input_img), figure_id=0, interp='bilinear', colormap=cm.jet, title='[GT:{}|P:{}]'.format(labels.data, predicted.data),alpha=0.2)

# %%
class HookBasedFeatureExtractor(nn.Module):
    def __init__(self, submodule, layername, upscale=False):
        super(HookBasedFeatureExtractor, self).__init__()

        self.submodule = submodule
        self.submodule.eval()
        self.layername = layername
        self.outputs_size = None
        self.outputs = None
        self.inputs = None
        self.inputs_size = None
        self.upscale = upscale

    def get_input_array(self, m, i, o):
        if isinstance(i, tuple):
            self.inputs = [i[index].data.clone() for index in range(len(i))]
            self.inputs_size = [input.size() for input in self.inputs]
        else:
            self.inputs = i.data.clone()
            self.inputs_size = self.input.size()
        print('Input Array Size: ', self.inputs_size)

    def get_output_array(self, m, i, o):
        if isinstance(o, tuple):
            self.outputs = [o[index].data.clone() for index in range(len(o))]
            self.outputs_size = [output.size() for output in self.outputs]
        else:
            self.outputs = o.data.clone()
            self.outputs_size = self.outputs.size()
        print('Output Array Size: ', self.outputs_size)

    def rescale_output_array(self, newsize):
        us = nn.Upsample(size=newsize[2:], mode='bilinear')
        if isinstance(self.outputs, list):
            for index in range(len(self.outputs)): self.outputs[index] = us(self.outputs[index]).data()
        else:
            self.outputs = us(self.outputs).data()

    def forward(self, x):
        target_layer = self.submodule._modules.get(self.layername)

        # Collect the output tensor
        h_inp = target_layer.register_forward_hook(self.get_input_array)
        h_out = target_layer.register_forward_hook(self.get_output_array)
        self.submodule(x)
        h_inp.remove()
        h_out.remove()

        # Rescale the feature-map if it's required
        if self.upscale: self.rescale_output_array(x.size())

        return self.inputs, self.outputs

# %%
dir_name = "./cifarplots"

# %%
for iteration in range(0,100):
    
    dataiter = iter(dataloader)
    images, labels = dataiter.next()

    input_img = images[0,0].cpu().numpy()
    input_img = np.expand_dims(input_img, axis=2)
    
    attentions=[]
    for i in [1,2]:
        feature_extractor = HookBasedFeatureExtractor(net, 'compatibility_score%d'%i, upscale=False)
        imap, fmap = feature_extractor.forward(images.cuda())

        fmap_0 = fmap[0].squeeze().permute(1,2,0).cpu().numpy()
        fmap_size = fmap_0.shape

        attention = fmap[1].squeeze().cpu().numpy()
        attention = attention[:, :]
        attention = np.expand_dims(resize(attention, (input_img.shape[0], input_img.shape[1]), mode='constant', preserve_range=True), axis=2)

        #plotNNFilterOverlay(input_img, attention, figure_id=i, interp='bilinear', colormap=cm.jet, title='[GT:{}|P:{}] compat. {}'.format(labels, predicted,i), alpha=0.5)
        attentions.append(attention)
        
    plotNNFilterOverlay(input_img, np.mean(attentions,0), figure_id=4, interp='bilinear', colormap=cm.jet, title='[GT:{}|P:{}] compat. (all)'.format(labels.cuda(), predicted), alpha=0.5)
    plt.savefig('{}/{:03d}_hm.png'.format(dir_name,iteration))
# Out:
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# ...
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 64, 8, 8]), torch.Size([1, 1, 8, 8])]
# Input Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 128, 2, 2])]
# Output Array Size:  [torch.Size([1, 128, 4, 4]), torch.Size([1, 1, 4, 4])]

# %%
plotNNFilterOverlay(input_img, np.mean(attentions,0), figure_id=4, interp='bilinear', colormap=cm.jet, title='[GT:{}|P:{}] compat. (all)'.format(labels, predicted), alpha=0.5)

# %% [markdown]
# Note: the attention seems to be offset from the signal distribution...  not quite sure why this is. Need to read the paper again.
